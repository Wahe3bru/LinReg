# %%
import pandas as pd

# %%
rates = pd.read_csv('data_source/interest_rates.csv')

# %%
rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 2 columns):
# Date     88 non-null object
# rates    88 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 1.5+ KB

# %%
futures = pd.read_csv('data_source/futures_prices.csv')

# %%
futures.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1873 entries, 0 to 1872
# Data columns (total 6 columns):
# Date      1873 non-null object
# Close     1873 non-null int64
# Open      1873 non-null int64
# High      1873 non-null int64
# Low       1873 non-null int64
# Change    1873 non-null float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 87.9+ KB

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics import tsaplots
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
fig= tsaplots.plot_acf(rates['rates'], lags=20)
plt.show()

# %%
fig= tsaplots.plot_acf(futures['Close'], lags=50)
plt.show()
